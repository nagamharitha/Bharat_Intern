# %% [markdown]
# **Google Stock Prediction**

# %% [markdown]
# # ABOUT DATASET

# %% [markdown]
# # PURPOSE : TO PREDICT THE STOCK PRICE OF A COMPANY USING LSTM.

# %% [markdown]
# This dataset contains historical data of Google's stock prices and related attributes. It consists of 14 columns and a smaller subset of 1257 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.
#
# The columns in the dataset are as follows:
#
# 1.Symbol: The name of the company, which is GOOG in this case.
#
# 2.Date: The year and date of the stock data.
#
# 3.Close: The closing price of Google's stock on a particular day.
#
# 4.High: The highest value reached by Google's stock on the given day.
#
# 5.Low: The lowest value reached by Google's stock on the given day.
#
# 6.Open: The opening value of Google's stock on the given day.
#
# 7.Volume: The trading volume of Google's stock on the given day, i.e., the number of shares traded.
#
# 8.adjClose: The adjusted closing price of Google's stock, considering factors such as dividends and stock splits.
#
# 9.adjHigh: The adjusted highest value reached by Google's stock on the given day.
#
# 10.adjLow: The adjusted lowest value reached by Google's stock on the given day.
#
# 11.adjOpen: The adjusted opening value of Google's stock on the given day.
#
# 12.adjVolume: The adjusted trading volume of Google's stock on the given day, accounting for factors such as stock splits.
#
# 13.divCash: The amount of cash dividend paid out to shareholders on the given day.
#
# 14.splitFactor: The split factor, if any, applied to Google's stock on the given day. A split factor of 1 indicates no split.
#
# The dataset is available at Kaggle : https://www.kaggle.com/datasets/shreenidhihipparagi/google-stock-prediction

# %% [markdown]
# # STEPS INVOLVED :

# %% [markdown]
# # 1 . IMPORTING LIBRARIES AND DATA TO BE USED

# %% [markdown]
# # 2. GATHERING INSIGHTS

# %% [markdown]
# # 3. DATA PRE-PROCESSING

# %% [markdown]
# # 4. CREATING LSTM MODEL

# %% [markdown]
# # 5. VISUALIZING ACTUAL VS PREDICTED DATA

# %% [markdown]
# # 6. PREDICTING UPCOMING 15 DAYS

# %% [markdown]
# # STEP 1 : IMPORTING LIBRARIES AND DATA TO BE USED

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/content/GOOG.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# # STEP 2 : GATHERING INSIGHTS

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# # STEP 3 : DATA PRE-PROCESSING

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
 train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# # STEP 4 : CREATING LSTM MODEL

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 8s 90ms/step - loss: 0.0101 - mean_absolute_error: 0.0687 - val_loss: 0.0220 - val_mean_absolute_error: 0.1263
# Epoch 2/100
# 28/28 [==============================] - 1s 53ms/step - loss: 9.0467e-04 - mean_absolute_error: 0.0239 - val_loss: 0.0046 - val_mean_absolute_error: 0.0531
# Epoch 3/100
# 28/28 [==============================] - 1s 54ms/step - loss: 4.5438e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0032 - val_mean_absolute_error: 0.0437
# Epoch 4/100
# 28/28 [==============================] - 1s 53ms/step - loss: 4.2280e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0029 - val_mean_absolute_error: 0.0406
# Epoch 5/100
# 28/28 [==============================] - 2s 54ms/step - loss: 4.1485e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0033 - val_mean_absolute_error: 0.0438
# Epoch 6/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.9711e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0033 - val_mean_absolute_error: 0.0432
# Epoch 7/100
# 28/28 [==============================] - 3s 95ms/step - loss: 3.9197e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0036 - val_mean_absolute_error: 0.0452
# Epoch 8/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.8764e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0046 - val_mean_absolute_error: 0.0531
# Epoch 9/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.8340e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0039 - val_mean_absolute_error: 0.0483
# Epoch 10/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.6301e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0053 - val_mean_absolute_error: 0.0577
# Epoch 11/100
# 28/28 [==============================] - 2s 59ms/step - loss: 3.6712e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0029 - val_mean_absolute_error: 0.0400
# Epoch 12/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.8105e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0047 - val_mean_absolute_error: 0.0529
# Epoch 13/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.5801e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0051 - val_mean_absolute_error: 0.0566
# Epoch 14/100
# 28/28 [==============================] - 2s 72ms/step - loss: 3.6151e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0046 - val_mean_absolute_error: 0.0526
# Epoch 15/100
# 28/28 [==============================] - 2s 80ms/step - loss: 3.3527e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0049 - val_mean_absolute_error: 0.0547
# Epoch 16/100
# 28/28 [==============================] - 1s 52ms/step - loss: 3.6212e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0039 - val_mean_absolute_error: 0.0472
# Epoch 17/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.2681e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0069 - val_mean_absolute_error: 0.0679
# Epoch 18/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.1166e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0067 - val_mean_absolute_error: 0.0662
# Epoch 19/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.9406e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0059 - val_mean_absolute_error: 0.0609
# Epoch 20/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.5250e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0034 - val_mean_absolute_error: 0.0444
# Epoch 21/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.2687e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0055 - val_mean_absolute_error: 0.0594
# Epoch 22/100
# 28/28 [==============================] - 2s 73ms/step - loss: 3.1985e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0034 - val_mean_absolute_error: 0.0442
# Epoch 23/100
# 28/28 [==============================] - 2s 78ms/step - loss: 3.1489e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0069 - val_mean_absolute_error: 0.0675
# Epoch 24/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.9183e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0043 - val_mean_absolute_error: 0.0502
# Epoch 25/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.6925e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0062 - val_mean_absolute_error: 0.0621
# Epoch 26/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.7339e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0055 - val_mean_absolute_error: 0.0571
# Epoch 27/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.8219e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0054 - val_mean_absolute_error: 0.0572
# Epoch 28/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.6710e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0042 - val_mean_absolute_error: 0.0493
# Epoch 29/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.8240e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0054 - val_mean_absolute_error: 0.0580
# Epoch 30/100
# 28/28 [==============================] - 2s 82ms/step - loss: 2.6337e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0051 - val_mean_absolute_error: 0.0553
# Epoch 31/100
# 28/28 [==============================] - 2s 69ms/step - loss: 2.5218e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0063 - val_mean_absolute_error: 0.0625
# Epoch 32/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.5463e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0043 - val_mean_absolute_error: 0.0493
# Epoch 33/100
# 28/28 [==============================] - 1s 54ms/step - loss: 2.4736e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0062 - val_mean_absolute_error: 0.0637
# Epoch 34/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.5838e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0045 - val_mean_absolute_error: 0.0513
# Epoch 35/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.5901e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0045 - val_mean_absolute_error: 0.0503
# Epoch 36/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.4640e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0062 - val_mean_absolute_error: 0.0624
# Epoch 37/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.3667e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0080 - val_mean_absolute_error: 0.0734
# Epoch 38/100
# 28/28 [==============================] - 3s 96ms/step - loss: 2.5087e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0047 - val_mean_absolute_error: 0.0540
# Epoch 39/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.5836e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0026 - val_mean_absolute_error: 0.0367
# Epoch 40/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.7265e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0047 - val_mean_absolute_error: 0.0523
# Epoch 41/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.7230e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0024 - val_mean_absolute_error: 0.0355
# Epoch 42/100
# 28/28 [==============================] - 1s 54ms/step - loss: 2.9725e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0055 - val_mean_absolute_error: 0.0619
# Epoch 43/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.5987e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0022 - val_mean_absolute_error: 0.0342
# Epoch 44/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.3305e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0056 - val_mean_absolute_error: 0.0611
# Epoch 45/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.1635e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0030 - val_mean_absolute_error: 0.0415
# Epoch 46/100
# 28/28 [==============================] - 3s 92ms/step - loss: 2.1383e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0028 - val_mean_absolute_error: 0.0401
# Epoch 47/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.2151e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0032 - val_mean_absolute_error: 0.0427
# Epoch 48/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.1158e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0043 - val_mean_absolute_error: 0.0509
# Epoch 49/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.0494e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0026 - val_mean_absolute_error: 0.0367
# Epoch 50/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.2038e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0042 - val_mean_absolute_error: 0.0504
# Epoch 51/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.0597e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0018 - val_mean_absolute_error: 0.0311
# Epoch 52/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.0970e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0028 - val_mean_absolute_error: 0.0397
# Epoch 53/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.0122e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0029 - val_mean_absolute_error: 0.0399
# Epoch 54/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.9103e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0057 - val_mean_absolute_error: 0.0615
# Epoch 55/100
# 28/28 [==============================] - 2s 74ms/step - loss: 2.0302e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0053 - val_mean_absolute_error: 0.0582
# Epoch 56/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.1495e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0046 - val_mean_absolute_error: 0.0556
# Epoch 57/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.0282e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0028 - val_mean_absolute_error: 0.0403
# Epoch 58/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.8790e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0039 - val_mean_absolute_error: 0.0497
# Epoch 59/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.7554e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0029 - val_mean_absolute_error: 0.0406
# Epoch 60/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.7599e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0026 - val_mean_absolute_error: 0.0382
# Epoch 61/100
# 28/28 [==============================] - 3s 91ms/step - loss: 1.8193e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0027 - val_mean_absolute_error: 0.0389
# Epoch 62/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.8049e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0019 - val_mean_absolute_error: 0.0316
# Epoch 63/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8473e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0015 - val_mean_absolute_error: 0.0281
# Epoch 64/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.7496e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0028 - val_mean_absolute_error: 0.0399
# Epoch 65/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.6022e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0033 - val_mean_absolute_error: 0.0432
# Epoch 66/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.5658e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0020 - val_mean_absolute_error: 0.0317
# Epoch 67/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7065e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0026 - val_mean_absolute_error: 0.0382
# Epoch 68/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.5675e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0048 - val_mean_absolute_error: 0.0563
# Epoch 69/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.9852e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0036 - val_mean_absolute_error: 0.0479
# Epoch 70/100
# 28/28 [==============================] - 1s 52ms/step - loss: 1.6086e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0026 - val_mean_absolute_error: 0.0379
# Epoch 71/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.5982e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0017 - val_mean_absolute_error: 0.0296
# Epoch 72/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.5873e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0022 - val_mean_absolute_error: 0.0357
# Epoch 73/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.3953e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0027 - val_mean_absolute_error: 0.0397
# Epoch 74/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.3897e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0017 - val_mean_absolute_error: 0.0296
# Epoch 75/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.5122e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0042 - val_mean_absolute_error: 0.0504
# Epoch 76/100
# 28/28 [==============================] - 2s 87ms/step - loss: 1.5531e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0038 - val_mean_absolute_error: 0.0491
# Epoch 77/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.3909e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292
# Epoch 78/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.4364e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0016 - val_mean_absolute_error: 0.0290
# Epoch 79/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.5411e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0049 - val_mean_absolute_error: 0.0568
# Epoch 80/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.3471e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0018 - val_mean_absolute_error: 0.0329
# Epoch 81/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4565e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0024 - val_mean_absolute_error: 0.0388
# Epoch 82/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.4010e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0024 - val_mean_absolute_error: 0.0359
# Epoch 83/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2795e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0025 - val_mean_absolute_error: 0.0371
# Epoch 84/100
# 28/28 [==============================] - 3s 111ms/step - loss: 1.2205e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0027 - val_mean_absolute_error: 0.0395
# Epoch 85/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.2105e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0014 - val_mean_absolute_error: 0.0270
# Epoch 86/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2956e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 87/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.3021e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266
# Epoch 88/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1541e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0032 - val_mean_absolute_error: 0.0453
# Epoch 89/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2029e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0024 - val_mean_absolute_error: 0.0388
# Epoch 90/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.1270e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0022 - val_mean_absolute_error: 0.0377
# Epoch 91/100
# 28/28 [==============================] - 2s 84ms/step - loss: 1.2004e-04 - mean_absolute_error: 0.0078 - val_loss: 9.6026e-04 - val_mean_absolute_error: 0.0228
# Epoch 92/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.1213e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0016 - val_mean_absolute_error: 0.0299
# Epoch 93/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.1343e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0026 - val_mean_absolute_error: 0.0397
# Epoch 94/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.1557e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 95/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.1067e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0014 - val_mean_absolute_error: 0.0277
# Epoch 96/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.1483e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 97/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.1087e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0028 - val_mean_absolute_error: 0.0428
# Epoch 98/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.1770e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0020 - val_mean_absolute_error: 0.0337
# Epoch 99/100
# 28/28 [==============================] - 3s 95ms/step - loss: 1.1012e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0018 - val_mean_absolute_error: 0.0316
# Epoch 100/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.1343e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 14ms/step
# array([[0.40716773, 0.4117903 ],
#        [0.40781862, 0.41227707],
#        [0.40498894, 0.40932953],
#        [0.40782022, 0.41226208],
#        [0.41120368, 0.41572177]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1425.8564, 1431.4475],
#        [1427.0631, 1432.3496],
#        [1421.8171, 1426.8868],
#        [1427.066 , 1432.3219],
#        [1433.3387, 1438.7339]], dtype=float32)

# %% [markdown]
# # STEP 5 : VISUALIZING ACTUAL VS PREDICTED DATA

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1425.856445      1431.447510
# 2020-05-28  1396.86  1416.73     1427.063110      1432.349609
# 2020-05-29  1416.94  1428.92     1421.817139      1426.886841
# 2020-06-01  1418.39  1431.82     1427.066040      1432.321899
# 2020-06-02  1430.55  1439.22     1433.338745      1438.733887

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# # STEP 6. PREDICTING UPCOMING 10 DAYS

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2358.063721      2365.609375
# 2021-06-10  2494.01  2521.60     2365.617676      2371.942871
# 2021-06-11  2524.92  2513.93     2381.131836      2387.259277
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# # THANK YOU!
